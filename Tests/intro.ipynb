# %% [markdown]
# # Uploading changes GitHub
# ```Bash
# git add .
# git commit -m "opis zmian"
# git push
# ls -R # pokazuje foldery
# git ls-files # pokazuje foldery na git
# ```
# # Killing processes on node "login":
# ```Bash
# scancel [JOBID]
# scancel -u swaliczek
# ```
# # Cluster in Notebooku:
# ```Python
# import ipyparallel as ipp
# # Profil zdefiniowany na Pauli: kwant_parallel
# cluster = ipp.Client(profile="kwant_parallel")
# v = cluster[:]
# lview = cluster.load_balanced_view()
# print(f"Liczba silników: {len(v)}")
# ```
# # Cluster usage
# Każda funkcja lub import, z którego korzysta docelowa funkcja obliczeniowa, musi być poprzedzona magią: %%px --local
#
# # Asynchronic mapping e.g.
# ```Python
# res = lview.map_async(lambda x: calculate_something(x, y=5), x_values)
# res.wait_interactive()
# y_values = res.get()
# ```
# # Start / Shutdown Cluster (Terminal)
# ```Bash
# # Profile local (Pauli)
# ipcluster start --profile=kwant_parallel -n 20 --daemonize
# ipcluster stop --profile=kwant_parallel
#
# # Profile Slurm
# ipcluster start --profile=slurm -n 20 --daemonize
# ipcluster stop --profile=slurm
# ```
# # Cleaning Slurm Profiles (when "hanging"):
# ```Bash
# cd ~/.ipython/profile_slurm/
# rm -f security/*.json
# rm -f log/*.log
# find . -name "*.ipc" -delete
# ```
# # Timer:
# ```Python
# import time
# start = time.time()
# # Miejsce na Twoje obliczenia (np. pętla po B)
# print(f"Czas obliczeń: {time.time() - start:.2f} s")
# ```
# # Aliases Slurm (add to ~/.bashrc):
# ```Bash
# alias slurm12h='srun --time=12:00:00 --mem=40G /bin/bash -l'
# alias scpu='python /net/home/mnowak/scripts/scpu.py'
# alias spart='python /net/home/mnowak/scripts/spartition.py'
# alias sconsumed='/net/home/mnowak/scripts/iconsumed.sc'
# ```
# # .ssh config and gener (Tera/Pauli):
# ```Bash
# mkdir -p ~/.ssh
# chmod 700 ~/.ssh
# cd ~/.ssh
# ssh-keygen -t rsa
# ```
#
# # Kopiowanie klucza na serwer Tera, aby logować się bez hasła
# ```
# ssh-copy-id -i ~/.ssh/id_rsa.pub swaliczek@tera
# ```
# # Plan praktyk ACMiN:
#
# 1. Środowisko: Zapoznanie się ze środowiskiem obliczeniowym i pakietami numerycznymi.
#
# 2. Teoria: Zaznajomienie się z podstawami fizycznymi zjawisk kwantowego efektu Halla oraz nadprzewodnictwa. Testowe symulacje numeryczne.
#
# 3. Analiza: Wstępne rachunki i analiza tworzenia się krawędziowych stanów Andreeva w złączu z trywialnym nadprzewodnikiem.
#
# 4. Symetria: Symulacje i analiza wpływu nietrywialnej symetrii parowania nadprzewodnika na formowanie się stanów krawędziowych.
#
# 5. Geometria: Przebadanie efektów geometrii struktury na formowanie się stanów Andreevałączu z trywialnym
#
#     nadprzewodnikiem.
#
# 4. Symulacje i analiza wpływu nietrywialnej symetrii parowania nadprzewodnika na formowanie się
#
#     stanów krawędziowych.
#
# 5. Przebadanie efektów geometrii struktury na formowanie się stanów Andreeva.uktury na formowanie się stanów Andreeva.
